# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # importing data

# %%
pune_data=pd.read_clipboard()

# %%
pune_data
# Out:
#           pH  Unnamed: 1    EC    OC       N      P       K      S    Zn  \
# 0        NaN         NaN   NaN   NaN     NaN    NaN     NaN    NaN   NaN
# 1       7.99         NaN  0.14  0.60   420.0  16.23   762.6  14.68  0.70
# 2       8.02         NaN  0.12  1.47  1029.0   8.33   199.6  15.75  0.76
# 3       8.04         NaN  0.21  1.71  1197.0   7.89   239.8  16.62  0.69
# 4       8.07         NaN  0.21  0.78   546.0  17.11   349.6  11.40  0.67
# ...      ...         ...   ...   ...     ...    ...     ...    ...   ...
# 189439  8.02         NaN  0.30  0.67   472.5  18.22   645.1  12.20  1.64
# 189440  7.93         NaN  0.32  0.37   262.5  10.15  1039.0  11.50  0.80
# 189441  8.10         NaN  0.37  0.67   472.5  12.25  1057.0  10.20  0.88
# 189442  7.96         NaN  0.35  0.22   157.5  11.05  1066.0  12.15  0.92
# 189443  7.99         NaN  0.38  0.07    52.5  11.95  1093.0  12.70  1.04
#
#            Fe    Cu  Unnamed: 11     Mn     B
# ...

# %%
punesoil_data=pd.DataFrame(pune_data)  #converting data into dataframe
print(punesoil_data)
# Out:
#           pH  Unnamed: 1    EC    OC       N      P       K      S    Zn  \
# 0        NaN         NaN   NaN   NaN     NaN    NaN     NaN    NaN   NaN
# 1       7.99         NaN  0.14  0.60   420.0  16.23   762.6  14.68  0.70
# 2       8.02         NaN  0.12  1.47  1029.0   8.33   199.6  15.75  0.76
# 3       8.04         NaN  0.21  1.71  1197.0   7.89   239.8  16.62  0.69
# 4       8.07         NaN  0.21  0.78   546.0  17.11   349.6  11.40  0.67
# ...      ...         ...   ...   ...     ...    ...     ...    ...   ...
# 189439  8.02         NaN  0.30  0.67   472.5  18.22   645.1  12.20  1.64
# 189440  7.93         NaN  0.32  0.37   262.5  10.15  1039.0  11.50  0.80
# 189441  8.10         NaN  0.37  0.67   472.5  12.25  1057.0  10.20  0.88
# 189442  7.96         NaN  0.35  0.22   157.5  11.05  1066.0  12.15  0.92
# 189443  7.99         NaN  0.38  0.07    52.5  11.95  1093.0  12.70  1.04
#
#            Fe    Cu  Unnamed: 11     Mn     B
# ...

# %%
punesoil_data.shape   # shape of given data
# Out:
# (189444, 14)

# %%
punesoil_data.head()     # top 5 observations
# Out:
#      pH  Unnamed: 1    EC    OC       N      P      K      S    Zn    Fe  \
# 0   NaN         NaN   NaN   NaN     NaN    NaN    NaN    NaN   NaN   NaN
# 1  7.99         NaN  0.14  0.60   420.0  16.23  762.6  14.68  0.70  11.3
# 2  8.02         NaN  0.12  1.47  1029.0   8.33  199.6  15.75  0.76  11.4
# 3  8.04         NaN  0.21  1.71  1197.0   7.89  239.8  16.62  0.69  17.1
# 4  8.07         NaN  0.21  0.78   546.0  17.11  349.6  11.40  0.67  11.5
#
#      Cu  Unnamed: 11    Mn     B
# 0   NaN          NaN   NaN   NaN
# 1  0.30          NaN  13.9  0.30
# 2  0.35          NaN  14.1  0.27
# 3  0.39          NaN  14.7  0.53
# 4  0.72          NaN  14.1  0.64

# %%
punesoil_data.tail()       # lower 5 observations
# Out:
#           pH  Unnamed: 1    EC    OC      N      P       K      S    Zn    Fe  \
# 189439  8.02         NaN  0.30  0.67  472.5  18.22   645.1  12.20  1.64  0.88
# 189440  7.93         NaN  0.32  0.37  262.5  10.15  1039.0  11.50  0.80  2.44
# 189441  8.10         NaN  0.37  0.67  472.5  12.25  1057.0  10.20  0.88  0.64
# 189442  7.96         NaN  0.35  0.22  157.5  11.05  1066.0  12.15  0.92  2.56
# 189443  7.99         NaN  0.38  0.07   52.5  11.95  1093.0  12.70  1.04  2.68
#
#           Cu  Unnamed: 11    Mn     B
# 189439  1.44          NaN  2.84  0.41
# 189440  1.24          NaN  4.44  0.47
# 189441  2.28          NaN  8.92  0.36
# 189442  1.36          NaN  4.56  0.52
# 189443  1.48          NaN  4.68  0.32

# %% [markdown]
# # Data cleaning

# %%
punesoil_data.isnull().sum()   #checking missing values
# Out:
# pH                 85
# Unnamed: 1     189444
# EC                115
# OC                455
# N                  86
# P                 112
# K                 121
# S                 152
# Zn                165
# Fe                224
# Cu               4129
# Unnamed: 11    189444
# Mn               5626
# B                 190
# dtype: int64

# %%
df1=punesoil_data.drop(['Unnamed: 1','Unnamed: 11'],axis='columns')  # Deliting Two missing columns
print(df1)
# Out:
#           pH    EC    OC       N      P       K      S    Zn     Fe    Cu  \
# 0        NaN   NaN   NaN     NaN    NaN     NaN    NaN   NaN    NaN   NaN
# 1       7.99  0.14  0.60   420.0  16.23   762.6  14.68  0.70  11.30  0.30
# 2       8.02  0.12  1.47  1029.0   8.33   199.6  15.75  0.76  11.40  0.35
# 3       8.04  0.21  1.71  1197.0   7.89   239.8  16.62  0.69  17.10  0.39
# 4       8.07  0.21  0.78   546.0  17.11   349.6  11.40  0.67  11.50  0.72
# ...      ...   ...   ...     ...    ...     ...    ...   ...    ...   ...
# 189439  8.02  0.30  0.67   472.5  18.22   645.1  12.20  1.64   0.88  1.44
# 189440  7.93  0.32  0.37   262.5  10.15  1039.0  11.50  0.80   2.44  1.24
# 189441  8.10  0.37  0.67   472.5  12.25  1057.0  10.20  0.88   0.64  2.28
# 189442  7.96  0.35  0.22   157.5  11.05  1066.0  12.15  0.92   2.56  1.36
# 189443  7.99  0.38  0.07    52.5  11.95  1093.0  12.70  1.04   2.68  1.48
#
#            Mn     B
# 0         NaN   NaN
# 1       13.90  0.30
# ...

# %%
df1.info()      # Information of given data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189444 entries, 0 to 189443
# Data columns (total 12 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   pH      189359 non-null  float64
#  1   EC      189329 non-null  float64
#  2   OC      188989 non-null  float64
#  3   N       189358 non-null  float64
#  4   P       189332 non-null  float64
#  5   K       189323 non-null  float64
#  6   S       189292 non-null  float64
#  7   Zn      189279 non-null  float64
#  8   Fe      189220 non-null  float64
#  9   Cu      185315 non-null  float64
#  10  Mn      183818 non-null  float64
#  11  B       189254 non-null  float64
# dtypes: float64(12)
# memory usage: 17.3 MB

# %%
df1['Mn']=df1['Mn'].fillna(df1['Mn'].mean())
df1['N']=df1['N'].fillna(df1['N'].mean())
df1['P']=df1['P'].fillna(df1['P'].mean())
df1['K']=df1['K'].fillna(df1['K'].mean())
df1['Zn']=df1['Zn'].fillna(df1['Zn'].mean())
df1['B']=df1['B'].fillna(df1['B'].mean())
df1['Cu']=df1['Cu'].fillna(df1['Cu'].mean())
df1['Fe']=df1['Fe'].fillna(df1['Fe'].mean())
df1['S']=df1['S'].fillna(df1['S'].mean())
df1['pH']=df1['pH'].fillna(df1['pH'].mean())
df1['EC']=df1['EC'].fillna(df1['EC'].mean())
df1['OC']=df1['OC'].fillna(df1['OC'].mean())   # Replacing missing values by its mean

# %%
df1.describe()        # Description of data after replacing missing values
# Out:
#                   pH             EC             OC              N  \
# count  189444.000000  189444.000000  189444.000000  189444.000000
# mean        7.815916       0.464437       0.692957     352.541079
# std         0.854855       0.873420       1.794439     235.781635
# min         0.000000       0.000000       0.000000       0.000000
# 25%         7.530000       0.220000       0.420000     198.800000
# 50%         7.830000       0.340000       0.580000     315.000000
# 75%         8.150000       0.530000       0.810000     445.000000
# max        89.950000      50.000000      98.000000    9240.000000
#
#                    P              K              S             Zn  \
# count  189444.000000  189444.000000  189444.000000  189444.000000
# mean       20.024890     424.882585      15.612663       1.427462
# std        72.129226     471.531798     219.416193      49.613716
# min         0.010000       0.000000       0.000000       0.000000
# ...

# %%
df2=df1[(df1.pH<14)&(df1.EC<1)&(df1.N<2000)]  #Filtering data 
df2.describe()                                # description after filtering
# Out:
#                   pH             EC             OC              N  \
# count  178455.000000  178455.000000  178455.000000  178455.000000
# mean        7.802551       0.367415       0.689271     351.371198
# std         0.576319       0.214280       1.825208     215.795161
# min         0.000000       0.000000       0.000000       0.000000
# 25%         7.520000       0.210000       0.410000     201.600000
# 50%         7.820000       0.320000       0.570000     315.000000
# 75%         8.140000       0.480000       0.790000     444.040000
# max        12.690000       0.990000      98.000000    1995.000000
#
#                    P              K              S             Zn  \
# count  178455.000000  178455.000000  178455.000000  178455.000000
# mean       19.791915     422.379799      14.886169       1.366510
# std        72.808904     477.320001     223.748402      39.023631
# min         0.010000       0.000000       0.000000       0.000000
# ...

# %%
df2.isnull().sum()       # checking missing values
# Out:
# pH    0
# EC    0
# OC    0
# N     0
# P     0
# K     0
# S     0
# Zn    0
# Fe    0
# Cu    0
# Mn    0
# B     0
# dtype: int64

# %%
df3=df2.drop_duplicates()    # Droping duplicates observations

# %%
df3.shape     # shape of data af data after cleaning
# Out:
# (169148, 12)

# %%
df3.describe()     # Description of data after cleaning
# Out:
#                   pH             EC             OC              N  \
# count  169148.000000  169148.000000  169148.000000  169148.000000
# mean        7.807533       0.376032       0.685260     346.164219
# std         0.582460       0.212561       1.869293     211.299975
# min         0.000000       0.000000       0.000000       0.000000
# 25%         7.540000       0.220000       0.410000     198.750000
# 50%         7.830000       0.330000       0.570000     315.000000
# 75%         8.140000       0.490000       0.780000     441.000000
# max        12.690000       0.990000      98.000000    1995.000000
#
#                    P              K              S             Zn  \
# count  169148.000000  169148.000000  169148.000000  169148.000000
# mean       20.095106     419.911097      15.257608       1.399831
# std        74.600185     485.355868     229.810826      40.081734
# min         0.010000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# # Checking outlier

# %%
Q1=df3.pH.quantile(0.25)   # 25 percentile for PH
Q3=df3.pH.quantile(0.75)    # 75 percentile for PH
Q1,Q3
IQR=Q3-Q1
IQR
lower_limit1=Q1-1.5*IQR
Upper_limit1=Q3+1.5*IQR
lower_limit1,Upper_limit1
# Out:
# (6.639999999999999, 9.040000000000001)

# %%
Q1=df3.N.quantile(0.25)   # 25 percentile for N
Q3=df3.N.quantile(0.75)    # 75 percentile for N
Q1,Q3
IQR=Q3-Q1
IQR
lower_limit2=Q1-1.5*IQR
Upper_limit2=Q3+1.5*IQR
lower_limit2,Upper_limit2
# Out:
# (-164.625, 804.375)

# %%
Q1=df3.OC.quantile(0.25)   # 25 percentile for OC
Q3=df3.OC.quantile(0.75)    # 75 percentile for OC
Q1,Q3
IQR=Q3-Q1
IQR
lower_limit3=Q1-1.5*IQR
Upper_limit3=Q3+1.5*IQR
lower_limit3,Upper_limit3
# Out:
# (-0.14500000000000007, 1.335)

# %%
Q1=df3.EC.quantile(0.25)   # 25 percentile for EC
Q3=df3.EC.quantile(0.75)    # 75 percentile for EC
Q1,Q3
IQR=Q3-Q1
IQR
lower_limit4=Q1-1.5*IQR
Upper_limit4=Q3+1.5*IQR
lower_limit4,Upper_limit4
# Out:
# (-0.18500000000000003, 0.895)

# %%
Q1=df3.P.quantile(0.25)   # 25 percentile for P
Q3=df3.P.quantile(0.75)    # 75 percentile for P
Q1,Q3
IQR=Q3-Q1
IQR
lower_limit5=Q1-1.5*IQR
Upper_limit5=Q3+1.5*IQR
lower_limit5,Upper_limit5
# Out:
# (-8.715000000000003, 37.485)

# %%
Q1=df3.K.quantile(0.25)   # 25 percentile for K
Q3=df3.K.quantile(0.75)    # 75 percentile for K
Q1,Q3
IQR=Q3-Q1
IQR
lower_limit6=Q1-1.5*IQR
Upper_limit6=Q3+1.5*IQR
lower_limit6,Upper_limit6
# Out:
# (-245.5, 1006.5)

# %%
sns.boxplot(x="pH",data=df3,color='blue')
# Out:
# <AxesSubplot:xlabel='pH'>

# %%
sns.boxplot(x="EC",data=df3,color='blue')
# Out:
# <AxesSubplot:xlabel='EC'>

# %%
sns.boxplot(x="OC",data=df3,color='blue')
# Out:
# <AxesSubplot:xlabel='OC'>

# %%
sns.boxplot(x="N",data=df3,color='blue')
# Out:
# <AxesSubplot:xlabel='N'>

# %%
sns.boxplot(x="P",data=df3,color='blue')
# Out:
# <AxesSubplot:xlabel='P'>

# %%
sns.boxplot(x="K",data=df3,color='blue')
# Out:
# <AxesSubplot:xlabel='K'>

# %%
sns.boxplot(x="Zn",data=df3,color='blue')
# Out:
# <AxesSubplot:xlabel='Zn'>

# %% [markdown]
# # outlier observations

# %%
df3[((df3.N>Upper_limit2)&(df3.pH>Upper_limit1)&(df3.OC>Upper_limit3)&(df3.EC>Upper_limit4)&(df3.P>Upper_limit5))
   |((df3.N<lower_limit2)&(df3.pH<lower_limit1)&(df3.OC<lower_limit3)&(df3.EC<lower_limit4)&(df3.P<lower_limit5))]   #Outlier observation
# Out:
#           pH    EC    OC      N     P      K      S    Zn    Fe    Cu    Mn  \
# 123667  9.11  0.91  2.84  824.6  40.3  56.34  81.09  4.16  2.57  2.56  3.99
#
#            B
# 123667  2.12

# %%
df4=df3[((df3.N<Upper_limit2)&(df3.pH<Upper_limit1)&(df3.OC<Upper_limit3)&(df3.EC<Upper_limit4)&(df3.P<Upper_limit5))
   |((df3.N>lower_limit2)&(df3.pH>lower_limit1)&(df3.OC>lower_limit3)&(df3.EC>lower_limit4)&(df3.P>lower_limit5))]  # Data afterremoving common ouliers

# %%
df4.shape
# Out:
# (167284, 12)

# %%
df4[(df4.N>Upper_limit2)|(df4.N<lower_limit2)].shape
# Out:
# (5689, 12)

# %%
df5=df4[(df4.N<Upper_limit2)&(df4.N>lower_limit2)]
df5.shape
# Out:
# (161595, 12)

# %%
df5[(df5.pH>Upper_limit1)|(df5.pH<lower_limit1)].shape
# Out:
# (4056, 12)

# %%
df6=df5[(df5.pH<Upper_limit1)&(df5.pH>lower_limit1)]

# %%
df6[(df6.EC>Upper_limit4)|(df6.EC<lower_limit4)].shape
# Out:
# (4093, 12)

# %%
df7=df6[(df6.EC<Upper_limit4)&(df6.EC>lower_limit4)]
df7.shape
# Out:
# (153446, 12)

# %%
df7[(df7.OC>Upper_limit3)|(df7.OC<lower_limit3)].shape
# Out:
# (4352, 12)

# %%
df8=df7[(df7.OC<Upper_limit3)&(df7.OC>lower_limit3)]
df8.shape
# Out:
# (149094, 12)

# %%
df8[(df8.K>Upper_limit6)|(df8.K<lower_limit6)&(df8.P>Upper_limit5)|(df8.P<lower_limit5)].shape
# Out:
# (4199, 12)

# %%
df9=df8[(df8.K<Upper_limit6)&(df8.K>lower_limit6)|(df8.P<Upper_limit5)|(df8.P>lower_limit5)]
df9.shape
# Out:
# (149094, 12)

# %% [markdown]
# # Exploratory Analysis

# %%
# !pip install klib

# %%
import klib as kb

# %%
kb.dist_plot(df9)
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <AxesSubplot:xlabel='B', ylabel='Density'>

# %%
df9.corr()
# Out:
#           pH        EC        OC         N         P         K         S  \
# pH  1.000000  0.046818  0.002637 -0.086060  0.005250 -0.035430  0.005815
# EC  0.046818  1.000000  0.017420  0.014103 -0.002262  0.035405  0.002060
# OC  0.002637  0.017420  1.000000  0.615238  0.022467 -0.028933 -0.001699
# N  -0.086060  0.014103  0.615238  1.000000  0.006963  0.043707  0.005403
# P   0.005250 -0.002262  0.022467  0.006963  1.000000 -0.005468  0.005152
# K  -0.035430  0.035405 -0.028933  0.043707 -0.005468  1.000000  0.005580
# S   0.005815  0.002060 -0.001699  0.005403  0.005152  0.005580  1.000000
# Zn  0.001492 -0.000934 -0.000696  0.000582  0.002737 -0.002363  0.000383
# Fe -0.099144 -0.057520  0.021111  0.006131  0.027639 -0.020728  0.001499
# Cu -0.017564 -0.025438  0.010551 -0.014217  0.022731 -0.008005  0.004148
# Mn -0.107995 -0.081200  0.049337  0.049833  0.043636 -0.012562  0.005001
# B  -0.005603  0.004128  0.005431 -0.004191  0.000063  0.003970 -0.000370
#
# ...

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df9.corr(),annot=True,cmap='coolwarm')
plt.title("multiple correlation matrix",fontsize=25)
# Out:
# Text(0.5, 1.0, 'multiple correlation matrix')

# %%
df10=df9[df9['pH']<6.5]

# %%
kb.dist_plot(df10)
# Out:
# No columns with numeric data were detected.

# %%
df10.corr()
# Out:
#     pH  EC  OC   N   P   K   S  Zn  Fe  Cu  Mn   B
# pH NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# EC NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# OC NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# N  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# P  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# K  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# S  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# Zn NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# Fe NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# Cu NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# Mn NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# B  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN

# %%
kb.corr_plot(df10)
# Out:
# E:\Program Files\Anaconda\lib\site-packages\klib\describe.py:365: RuntimeWarning: All-NaN axis encountered
#   vmax = np.round(np.nanmax(corr.where(~mask)) - 0.05, 2)
# E:\Program Files\Anaconda\lib\site-packages\klib\describe.py:366: RuntimeWarning: All-NaN axis encountered
#   vmin = np.round(np.nanmin(corr.where(~mask)) + 0.05, 2)
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
df11=df9[df9['pH']>7.5]

# %%
kb.dist_plot(df11)
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <AxesSubplot:xlabel='B', ylabel='Density'>

# %%
df11.corr()
# Out:
#           pH        EC        OC         N         P         K         S  \
# pH  1.000000  0.004145  0.046131 -0.182563  0.030756 -0.076622  0.003698
# EC  0.004145  1.000000  0.013923 -0.040280 -0.005334  0.024523  0.001694
# OC  0.046131  0.013923  1.000000  0.620890  0.031686 -0.040221 -0.001232
# N  -0.182563 -0.040280  0.620890  1.000000  0.020323  0.042289  0.006863
# P   0.030756 -0.005334  0.031686  0.020323  1.000000 -0.001747  0.005362
# K  -0.076622  0.024523 -0.040221  0.042289 -0.001747  1.000000  0.006541
# S   0.003698  0.001694 -0.001232  0.006863  0.005362  0.006541  1.000000
# Zn  0.000711 -0.001958  0.000127  0.001693  0.002866 -0.002582  0.000175
# Fe -0.034997 -0.040610  0.024771  0.020036  0.021075 -0.012180  0.000880
# Cu  0.022889 -0.012194  0.010209  0.002009  0.019960 -0.004673  0.003763
# Mn  0.013386 -0.057260  0.046244  0.117468  0.034539 -0.013249  0.006289
# B   0.002625  0.010225  0.006447  0.001569 -0.001002  0.003283 -0.000183
#
# ...

# %%
kb.corr_plot(df11)
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
df12=df9[(df9['pH']<7.5)&(df9['pH']>6.5)]

# %%
kb.dist_plot(df12)
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <AxesSubplot:xlabel='B', ylabel='Density'>

# %%
df12.corr()
# Out:
#           pH        EC        OC         N         P         K         S  \
# pH  1.000000  0.155732 -0.056851  0.128459 -0.025406  0.044822  0.000144
# EC  0.155732  1.000000  0.035786  0.186807  0.019968  0.088237  0.001545
# OC -0.056851  0.035786  1.000000  0.594261 -0.021895  0.041235 -0.003620
# N   0.128459  0.186807  0.594261  1.000000 -0.035285  0.041133 -0.001827
# P  -0.025406  0.019968 -0.021895 -0.035285  1.000000 -0.022884  0.005379
# K   0.044822  0.088237  0.041235  0.041133 -0.022884  1.000000 -0.006236
# S   0.000144  0.001545 -0.003620 -0.001827  0.005379 -0.006236  1.000000
# Zn  0.003754  0.003252 -0.003847 -0.003666  0.002050 -0.000820  0.001919
# Fe -0.065683 -0.082561  0.012177 -0.002329  0.037306 -0.049954  0.008750
# Cu -0.063834 -0.058774  0.008899 -0.059776  0.027084 -0.017871  0.009357
# Mn -0.168759 -0.118009  0.060420 -0.072240  0.064412  0.003411  0.006266
# B  -0.011164 -0.019040 -0.001181 -0.031244  0.004557  0.011295 -0.001360
#
# ...

# %%
kb.corr_plot(df12)
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
df13=df9[(df9['pH']<7.5)&(df9['pH']>6.5)&(df9['EC']<0.4)]
kb.dist_plot(df13)
df13.corr()
kb.corr_plot(df13)
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
df14=df9[(df9['pH']<7.5)&(df9['pH']>6.5)&(df9['EC']>0.6)]
kb.dist_plot(df14)
df13.corr()
kb.corr_plot(df14)
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
df15=df9[(df9['pH']<7.5)&(df9['pH']>6.5)&(df9['EC']>0.4)&(df9['EC']<0.6)]
kb.dist_plot(df15)
df13.corr()
kb.corr_plot(df15)
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %% [markdown]
# ##Normality checking of data

# %%
# !pip install scipy

# %%
from scipy.stats import shapiro

# %%
stat, p = shapiro(df9['pH'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Sample looks Gaussian (fail to reject H0)')
else:
	print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.997, p=0.000
# Sample does not look Gaussian (reject H0)
# E:\Program Files\Anaconda\lib\site-packages\scipy\stats\morestats.py:1760: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
stat, p = shapiro(df9['N'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Sample looks Gaussian (fail to reject H0)')
else:
	print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.975, p=0.000
# Sample does not look Gaussian (reject H0)

# %%
stat, p = shapiro(df9)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Sample looks Gaussian (fail to reject H0)')
else:
	print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.277, p=0.000
# Sample does not look Gaussian (reject H0)

# %%
# !pip install sklearn

# %%
# create a regresion model to predict values of N by train and test method
from sklearn.ensemble import RandomForestRegressor
clf = RandomForestRegressor()

# train the model
clf.fit(df9[['pH','EC','OC']], df9['N'])

# predict on test data
predict = clf.predict(test_data[['x','y','z']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5620/4021867652.py in <module>
#       7
#       8 # predict on test data
# ----> 9 predict = clf.predict(test_data[['x','y','z']])
#
# NameError: name 'test_data' is not defined

# %%
#applying regression model to testing data and improve performance

# %%
#Stop the process
